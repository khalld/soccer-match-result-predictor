# %% [markdown]
# <b>Esercizio 1</b>
#
# Si carichi il dataset disponibile al seguente URL: https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv in modo da utilizzare i valori della colonna "PassengerId" come indici e si applichino le seguenti trasfromazioni:
#
#  * Si rimuovano le righe che contengono dei valori NaN;
#  * Si modifichi il DataFrame sostituendo nella colonna "Sex" ogni occorrenza di "male" con "M" e ogni occorrenza di "female" con "F";
#  * Si inserisca una nuova colonna "Old" con valore pari a "1" se Age è superiore all'età media dei passeggeri e "0" altrimenti;
#  * Si convertano i valori della colonna "Age" in interi.

# %%
import pandas as pd
dataset = pd.read_csv("https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/train.csv", index_col="PassengerId")

# %%
dataset.shape
# Out:
# (891, 11)

# %%
dataset.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C

# %%
new_ds = dataset.dropna().copy()

# %%
new_ds.replace(
    to_replace=['male', 'female'],
    value=['M', 'F'],
    inplace=True)

# %%
new_ds.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
#
#                                                           Name Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0
# 7                                      McCarthy, Mr. Timothy J   M  54.0
# 11                             Sandstrom, Miss. Marguerite Rut   F   4.0
# 12                                    Bonnell, Miss. Elizabeth   F  58.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 7                0      0     17463  51.8625   E46        S
# 11               1      1   PP 9549  16.7000    G6        S
# 12               0      0    113783  26.5500  C103        S

# %%
new_ds['Old'] = 0

# %%
new_ds.loc[new_ds['Age'] > new_ds['Age'].mean(), 'Old'] = 1

# %%
new_ds['Age'] = new_ds['Age'].astype(int)

# %%
new_ds.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
#
#                                                           Name Sex  Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   F   38
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   F   35
# 7                                      McCarthy, Mr. Timothy J   M   54
# 11                             Sandstrom, Miss. Marguerite Rut   F    4
# 12                                    Bonnell, Miss. Elizabeth   F   58
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked  Old
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C    1
# 4                1      0    113803  53.1000  C123        S    0
# 7                0      0     17463  51.8625   E46        S    1
# 11               1      1   PP 9549  16.7000    G6        S    0
# 12               0      0    113783  26.5500  C103        S    1

# %%
new_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 2 to 890
# Data columns (total 12 columns):
# Survived    183 non-null int64
# Pclass      183 non-null int64
# Name        183 non-null object
# Sex         183 non-null object
# Age         183 non-null int32
# SibSp       183 non-null int64
# Parch       183 non-null int64
# Ticket      183 non-null object
# Fare        183 non-null float64
# Cabin       183 non-null object
# Embarked    183 non-null object
# Old         183 non-null int64
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 17.9+ KB

# %% [markdown]
# <b>Esercizio 2</b>
#
# Si consideri il dataset caricato e modificato nell'esercizio precedente. Si trovi il nome del passeggero con ticket dal codice "PP 9549".

# %%
ticket = 'PP 9549'

# %%
new_ds.loc[new_ds['Ticket'] == ticket, ['Name']]
# Out:
#                                                           Name
# PassengerId
# 11                             Sandstrom, Miss. Marguerite Rut
# 395          Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...

# %% [markdown]
# <b>Esercizio 3</b>
#
# Quali sono i nomi e le età dei 5 passeggeri più giovani?

# %%
new_ds[['Name','Age']].sort_values(by = 'Age').head(5)
#equivalente a new_ds.sort_values(by = 'Age').loc[:, ['Name', 'Age']].head(5)
# Out:
#                                        Name  Age
# PassengerId
# 306          Allison, Master. Hudson Trevor    0
# 184               Becker, Master. Richard F    1
# 206              Strom, Miss. Telma Matilda    2
# 298            Allison, Miss. Helen Loraine    2
# 341          Navratil, Master. Edmond Roger    2

# %% [markdown]
# <b>Esercizio 4</b>
#
# Si consideri il dataset caricato e modificato nell'esercizio precedente. Si selezionino tutte le osservazioni relative a passeggeri di età compresa tra 20 e 30 anni.

# %%
new_ds[(new_ds['Age']>=20) & (new_ds['Age']<=30)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 24                  1       1
# 67                  1       2
# 76                  0       3
# 89                  1       1
# 98                  1       1
# 103                 0       1
# 119                 0       1
# 140                 0       1
# 152                 1       1
# 252                 0       3
# 258                 1       1
# 310                 1       1
# 311                 1       1
# 337                 0       1
# 342                 1       1
# 346                 1       2
# 357                 1       1
# 370                 1       1
# 371                 1       1
# 378                 0       1
# 394                 1       1
# 395                 1       3
# 431                 1       1
# 453                 0       1
# 474                 1       2
# 485                 1       1
# 499                 0       1
# 521                 1       1
# 540                 1       1
# 628                 1       1
# 642                 1       1
# 682                 1       1
# 711                 1       1
# 718                 1       2
# 725                 1       1
# 731                 1       1
# 743                 1       1
# 783                 0       1
# 824                 1       3
# 890                 1       1
#
#                                                           Name Sex  Age  \
# PassengerId
# 24                                Sloper, Mr. William Thompson   M   28
# 67                                Nye, Mrs. (Elizabeth Ramell)   F   29
# 76                                     Moen, Mr. Sigurd Hansen   M   25
# 89                                  Fortune, Miss. Mabel Helen   F   23
# 98                             Greenfield, Mr. William Bertram   M   23
# 103                                  White, Mr. Richard Frasar   M   21
# 119                                   Baxter, Mr. Quigg Edmond   M   24
# 140                                         Giglio, Mr. Victor   M   24
# 152                          Pears, Mrs. Thomas (Edith Wearne)   F   22
# 252                 Strom, Mrs. Wilhelm (Elna Matilda Persson)   F   29
# 258                                       Cherry, Miss. Gladys   F   30
# 310                             Francatelli, Miss. Laura Mabel   F   30
# 311                             Hays, Miss. Margaret Bechstein   F   24
# 337                                  Pears, Mr. Thomas Clinton   M   29
# 342                             Fortune, Miss. Alice Elizabeth   F   24
# 346                              Brown, Miss. Amelia "Mildred"   F   24
# 357                                Bowerman, Miss. Elsie Edith   F   22
# 370                              Aubart, Mme. Leontine Pauline   F   24
# 371                                Harder, Mr. George Achilles   M   25
# 378                                  Widener, Mr. Harry Elkins   M   27
# 394                                     Newell, Miss. Marjorie   F   23
# 395          Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...   F   24
# 431                  Bjornstrom-Steffansson, Mr. Mauritz Hakan   M   28
# 453                            Foreman, Mr. Benjamin Laventall   M   30
# 474               Jerwan, Mrs. Amin S (Marie Marthe Thuillard)   F   23
# 485                                    Bishop, Mr. Dickinson H   M   25
# 499            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 628                S    0
# 642                C    0
# 682                C    0
# 711                C    0
# 718                S    0
# 725                S    0
# 731                S    0
# 743                C    0
# 783                S    0
# 824                S    0
# 890                C    0

# %% [markdown]
# <b>Esercizio 5</b>
#
# Si consideri il dataset caricato e modificato negli esercizi precedenti. Si calcoli la tariffa media pagata dai passeggeri di sesso femminile in seconda classe.

# %%
new_ds.loc[(new_ds['Pclass']==2) & (new_ds['Sex']=='F'),'Fare'].mean()
# Out:
# 14.865744444444443

# %%
new_ds[(new_ds['Pclass']==2) & (new_ds['Sex']=='F')]['Fare'].mean()
# Out:
# 14.865744444444443

# %% [markdown]
# <b>Esercizio 6</b>
#
# Si consideri il dataset caricato e modificato negli esercizi precedenti. Si costruisca una crosstab che permetta di rispondere alle seguenti domande:
#  * Quanti passeggeri di sesso maschile sono sopravvisuti?
#  * Quanti passeggeri di sesso femminile non sono sopravvisuti?

# %%
print(pd.crosstab(new_ds['Survived'],new_ds['Sex']),"\n")
Msurv = pd.crosstab(new_ds['Survived'],new_ds['Sex']).iloc[1,1]
print("Uomini sopravvissuti: ", Msurv)
Fnsurv= pd.crosstab(new_ds['Survived'],new_ds['Sex']).iloc[0,0]
print("Donne non sopravvissute: ", Fnsurv)
# Out:
# Sex        F   M
# Survived
# 0          6  54
# 1         82  41
#
# Uomini sopravvissuti:  41
# Donne non sopravvissute:  6

# %% [markdown]
# <b>Esercizio 7</b>
#
# Si consideri il dataset caricato e modificato negli esercizi precedenti. Si costruisca una crosstab che permetta di rispondere alle seguenti domande:
#  * Quanti passeggeri di sesso maschile sono sopravvisuti in prima classe?
#  * Quanti passeggeri di sesso femminile sono sopravvisuti in terza classe?
#  * Quanti passeggeri di sesso maschile sono sopravvisuti in terza classe?

# %%
pd.crosstab(new_ds['Survived'], [new_ds['Sex'],new_ds['Pclass']])
# Out:
# Sex        F         M
# Pclass     1  2  3   1  2  3
# Survived
# 0          3  1  2  49  2  3
# 1         71  8  3  35  4  2

# %%
pd.crosstab(new_ds['Survived'], [(new_ds['Sex']=='M')&(new_ds['Pclass']==1)])
# Out:
# col_0     False  True
# Survived
# 0            11     49
# 1            88     35

# %%
Msurv1 = pd.crosstab(new_ds['Survived'], [(new_ds['Sex']=='M')&(new_ds['Pclass']==1)]).iloc[1,1]
print("Uomini sopravvissuti in prima classe: ", Msurv1)
Fsurv3 = pd.crosstab(new_ds['Survived'], [(new_ds['Sex']=='F')&(new_ds['Pclass']==3)]).iloc[1,1]
print("Donne sopravvissute in terza classe: ", Fsurv3)
Msurv3 = pd.crosstab(new_ds['Survived'], [(new_ds['Sex']=='M')&(new_ds['Pclass']==3)]).iloc[1,1]
print("Uomini sopravvissuti in terza classe: ", Msurv3)
# Out:
# Uomini sopravvissuti in prima classe:  35
# Donne sopravvissute in terza classe:  3
# Uomini sopravvissuti in terza classe:  2
